# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv ('models/WS_FV_2021_1_25_9_30_55_top_bottom_train_top_test_bottom_first_train_bottom_test_bottom_second_stage_check/performance.csv')
# df = pd.read_csv ('models/WS_FV_2021_1_7_15_38_49_omit_tro2_shape_second_train_omit_only/Polyomino World - tro1 data - Sheet1.csv')
# print(df)

# WS_FV_2020_2_9_12_8_30
# WS_FV_2020_12_26_15_42_19_rotate
# WS_FV_2020_12_28_15_43_11_omit_black_color_first_train
# WS_FV_2020_12_28_15_43_11_omit_black_color_second_train
# WS_FV_2020_12_28_15_43_11_omit_black_color_second_train_complete
# WS_FV_2020_12_28_15_43_11_omit_black_color_second_train_complete_epo1
# WS_FV_2020_12_28_15_43_11_omit_black_color_second_train_epo1
# WS_FV_2020_12_28_17_0_28_omit_tetro1_shape_first_train
# WS_FV_2020_12_28_17_0_28_omit_tetro1_shape_second_train
# WS_FV_2020_12_28_17_0_28_omit_tetro1_shape_second_train_(first_omit_second_complete)
# WS_FV_2020_12_28_17_0_28_omit_tetro1_shape_second_train_complete_epo10
# WS_FV_2020_12_28_17_0_28_omit_tetro1_shape_second_train_epo_1
# WS_FV_2020_12_28_19_33_20_top_bottom_first_train
# WS_FV_2020_12_28_19_33_20_top_bottom_second_train
# WS_FV_2020_12_28_19_33_20_top_bottom_second_train_complete
# WS_FV_2021_1_1_15_39_23_omit_tetro1_shape_first_stage_train_&_test_complete_epo5
# WS_FV_2021_1_1_15_39_23_omit_tetro1_shape_second_stage_train_&_test_complete_epo5
# WS_FV_2021_1_1_17_42_20_omit_tetro1_color_first_stage_train_&_test_complete_epo5
# WS_FV_2021_1_1_17_42_20_omit_tetro1_color_second_stage_train_&_test_complete_epo5
# WS_FV_2021_1_1_19_44_53_top_bottom_first_stage_train_&_test_complete_epo5
# WS_FV_2021_1_1_19_44_53_top_bottom_second_stage_train_&_test_complete_epo5
# WS_FV_2021_1_2_0_15_38_omit_black_color_first_train
# WS_FV_2021_1_2_0_15_38_omit_black_color_second_train_complete
# WS_FV_2021_1_2_0_15_38_omit_black_color_second_train_test_one_color
# WS_FV_2021_1_3_16_12_19_omit_black_color_first_train_(test_omit_only)
# WS_FV_2021_1_3_16_12_19_omit_black_color_second_train_(first_omit_second_complete)
# WS_FV_2021_1_3_16_12_19_omit_black_color_second_train_(test_omit_only)
# WS_FV_2021_1_6_18_6_8_half_variant_first_train(one_action)
# WS_FV_2021_1_6_18_6_8_half_variant_second_train(one_action)_complete
# WS_FV_2021_1_6_18_6_8_half_variant_second_train(one_action)_omit_only
# WS_FV_2021_1_6_23_29_45_omit_mono_shape_first_train
# WS_FV_2021_1_6_23_29_45_omit_mono_shape_second_train_complete
# WS_FV_2021_1_6_23_29_45_omit_mono_shape_second_train_omit_only
# WS_FV_2021_1_7_15_29_44_omit_domino_shape_first_train
# WS_FV_2021_1_7_15_29_44_omit_domino_shape_second_train_complete
# WS_FV_2021_1_7_15_29_44_omit_domino_shape_second_train_omit_only
# WS_FV_2021_1_7_15_35_23_omit_tro1_shape_first_train
# WS_FV_2021_1_7_15_35_23_omit_tro1_shape_second_train_complete
# WS_FV_2021_1_7_15_35_23_omit_tro1_shape_second_train_omit_only
# WS_FV_2021_1_7_15_38_49_omit_tro2_shape_first_train
# WS_FV_2021_1_7_15_38_49_omit_tro2_shape_second_train_complete
# WS_FV_2021_1_7_15_38_49_omit_tro2_shape_second_train_omit_only
# WS_FV_2021_1_7_15_40_43_omit_tetro2_shape_first_train
# WS_FV_2021_1_7_15_40_43_omit_tetro2_shape_second_train_complete
# WS_FV_2021_1_7_15_40_43_omit_tetro2_shape_second_train_omit_only
# WS_FV_2021_1_7_15_41_51_omit_tetro3_shape_first_train
# WS_FV_2021_1_7_15_41_51_omit_tetro3_shape_second_train_complete
# WS_FV_2021_1_7_15_41_51_omit_tetro3_shape_second_train_omit_only
# WS_FV_2021_1_7_17_38_1_omit_tetro4_shape_first_train
# WS_FV_2021_1_7_17_38_1_omit_tetro4_shape_second_train_complete
# WS_FV_2021_1_7_17_38_1_omit_tetro4_shape_second_train_omit_only
# WS_FV_2021_1_7_17_39_7_omit_tetro5_shape_first_train
# WS_FV_2021_1_7_17_39_7_omit_tetro5_shape_second_train_complete
# WS_FV_2021_1_7_17_39_7_omit_tetro5_shape_second_train_omit_only
# WS_FV_2021_1_7_17_41_33_omit_white_color_first_train
# WS_FV_2021_1_7_17_41_33_omit_white_color_second_train_complete
# WS_FV_2021_1_7_17_41_33_omit_white_color_second_train_omit_only
# WS_FV_2021_1_7_17_45_15_omit_blue_color_first_train
# WS_FV_2021_1_7_17_45_15_omit_blue_color_second_train_complete
# WS_FV_2021_1_7_17_45_15_omit_blue_color_second_train_omit_only
# WS_FV_2021_1_7_21_48_27_omit_magenta_color_first_train
# WS_FV_2021_1_7_21_48_27_omit_magenta_color_second_train_complete
# WS_FV_2021_1_7_21_48_27_omit_magenta_color_second_train_omit_only
# WS_FV_2021_1_7_21_48_55_omit_cyan_color_first_train
# WS_FV_2021_1_7_21_48_55_omit_cyan_color_second_train_complete
# WS_FV_2021_1_7_21_48_55_omit_cyan_color_second_train_omit_only
# WS_FV_2021_1_7_21_49_34_omit_yellow_color_first_train
# WS_FV_2021_1_7_21_49_34_omit_yellow_color_second_train_complete
# WS_FV_2021_1_7_21_49_34_omit_yellow_color_second_train_omit_only
# WS_FV_2021_1_7_21_50_34_omit_green_color_first_train
# WS_FV_2021_1_7_21_50_34_omit_green_color_second_train_complete
# WS_FV_2021_1_7_21_50_34_omit_green_color_second_train_omit_only
# WS_FV_2021_1_8_0_32_57_omit_red_color_first_train
# WS_FV_2021_1_8_0_32_57_omit_red_color_second_train_complete
# WS_FV_2021_1_8_0_32_57_omit_red_color_second_train_omit_only
# WS_FV_2021_1_14_14_26_53_complete_train
# WS_FV_2021_1_14_21_21_32_omit_mono_shape_both_complete_first_stage
# WS_FV_2021_1_14_21_21_32_omit_mono_shape_both_complete_second_stage
# WS_FV_2021_1_14_21_22_30_omit_domino_shape_both_complete_first_stage
# WS_FV_2021_1_14_21_22_30_omit_domino_shape_both_complete_second_stage
# WS_FV_2021_1_14_21_23_38_omit_tro1_shape_both_complete_first_stage
# WS_FV_2021_1_14_21_23_38_omit_tro1_shape_both_complete_second_stage
# WS_FV_2021_1_14_21_25_17_omit_tro2_shape_both_complete_first_stage
# WS_FV_2021_1_14_21_25_17_omit_tro2_shape_both_complete_second_stage
# WS_FV_2021_1_14_21_26_12_omit_tetro1_shape_both_complete_first_stage
# WS_FV_2021_1_14_21_26_12_omit_tetro1_shape_both_complete_second_stage
# WS_FV_2021_1_14_21_27_15_omit_tetro2_shape_both_complete_first_stage
# WS_FV_2021_1_14_21_27_15_omit_tetro2_shape_both_complete_second_stage
# WS_FV_2021_1_14_21_28_7_omit_tetro3_shape_both_complete_first_stage
# WS_FV_2021_1_14_21_28_7_omit_tetro3_shape_both_complete_second_stage
# WS_FV_2021_1_14_21_29_3_omit_tetro4_shape_both_complete_first_stage
# WS_FV_2021_1_14_21_29_3_omit_tetro4_shape_both_complete_second_stage
# WS_FV_2021_1_14_21_29_52_omit_tetro5_shape_both_complete_first_stage
# WS_FV_2021_1_14_21_29_52_omit_tetro5_shape_both_complete_second_stage
# WS_FV_2021_1_14_21_30_15_omit_black_color_both_complete_first_stage
# WS_FV_2021_1_14_21_30_15_omit_black_color_both_complete_first_stage_6k
# WS_FV_2021_1_14_21_30_15_omit_black_color_both_complete_second_stage
# WS_FV_2021_1_14_21_31_24_omit_white_color_both_complete_first_stage
# WS_FV_2021_1_14_21_31_24_omit_white_color_both_complete_second_stage
# WS_FV_2021_1_14_21_32_20_omit_red_color_both_complete_first_stage
# WS_FV_2021_1_14_21_32_20_omit_red_color_both_complete_second_stage
# WS_FV_2021_1_14_21_33_20_omit_blue_color_both_complete_first_stage
# WS_FV_2021_1_14_21_33_20_omit_blue_color_both_complete_second_stage
# WS_FV_2021_1_14_21_34_15_omit_green_color_both_complete_first_stage
# WS_FV_2021_1_14_21_34_15_omit_green_color_both_complete_second_stage
# WS_FV_2021_1_14_21_35_18_omit_yellow_color_both_complete_first_stage
# WS_FV_2021_1_14_21_35_18_omit_yellow_color_both_complete_second_stage
# WS_FV_2021_1_14_21_36_10_omit_cyan_color_both_complete_first_stage
# WS_FV_2021_1_14_21_36_10_omit_cyan_color_both_complete_second_stage
# WS_FV_2021_1_14_21_37_3_omit_magenta_color_both_complete_first_stage
# WS_FV_2021_1_14_21_37_3_omit_magenta_color_both_complete_second_stage
# WS_FV_2021_1_16_15_35_49_complete_full_actions
# WS_FV_2021_1_16_15_57_47_top_bottom_first_train
# WS_FV_2021_1_16_15_57_47_top_bottom_second_train_complete_test
# WS_FV_2021_1_16_15_57_47_top_bottom_second_train_test_bottom
# WS_FV_2021_1_18_21_52_8_complete_full_actions_1epo
# WS_FV_2021_1_18_21_54_54_omit_black_color_first_stage_both_complete_1epo
# WS_FV_2021_1_18_21_54_54_omit_black_color_second_stage_both_complete_1epo
# WS_FV_2021_1_22_14_7_57_half_variant_both_complete_test_first_stage
# WS_FV_2021_1_22_14_7_57_half_variant_both_complete_test_second_stage
# WS_FV_2021_1_22_14_9_57_top_bottom_both_complete_test_first_stage
# WS_FV_2021_1_22_14_9_57_top_bottom_both_complete_test_second_stage
# WS_FV_2021_1_21_13_10_39_top_bottom_both_complete_test_second_stage
# WS_FV_2021_1_22_14_7_57_half_variant_complete_train_complete_test_second_stage
# WS_FV_2021_1_22_14_7_57_half_variant_train_complete_test_omit_second_stage
# WS_FV_2021_1_22_14_7_57_half_variant_train_first_test_complete_first_stage
# WS_FV_2021_1_22_14_7_57_half_variant_train_second_test_complete_second_stage
# WS_FV_2021_1_22_14_7_57_half_variant_train_second_test_omit_second_stage
# WS_FV_2021_1_24_13_34_34_top_bottom_both_complete_test_first_stage
# WS_FV_2021_1_24_13_34_34_top_bottom_both_complete_test_second_stage
# WS_FV_2021_1_24_13_34_34_top_bottom_train_bottom_test_bottom_second_stage
# WS_FV_2021_1_24_13_34_34_top_bottom_train_complete_test_bottom_second_stage
# WS_FV_2021_1_24_13_34_34_top_bottom_train_complete_test_complete_second_stage
# WS_FV_2021_1_24_14_5_25_half_variant_train_first_test_omit_first_stage
# WS_FV_2021_1_24_18_7_12_top_bottom_train_top_test_bottom_first_stage
# WS_WS_2020_2_9_10_44_25
# WS_WS_2020_2_9_12_9_14

# %%
df_end = df.tail(1)
print(df_end.columns)

# df_end = df.iloc[40, :]
# print(df_end)
# Out:
# Index(['epoch', 'time', 'training_cost', 'test_cost', 'shape_training_cost',
#        'size_training_cost', 'color_training_cost', 'shape_test_cost',
#        'size_test_cost', 'color_test_cost', 'shape_training_accuracy',
#        'size_training_accuracy', 'color_training_accuracy',
#        'shape_test_accuracy', 'size_test_accuracy', 'color_test_accuracy',
#        'monomino_training_accuracy', 'domino_training_accuracy',
#        'tromino1_training_accuracy', 'tromino2_training_accuracy',
#        'tetromino1_training_accuracy', 'tetromino2_training_accuracy',
#        'tetromino3_training_accuracy', 'tetromino4_training_accuracy',
#        'tetromino5_training_accuracy', '1_training_accuracy',
#        '2_training_accuracy', '3_training_accuracy', '4_training_accuracy',
#        'black_training_accuracy', 'white_training_accuracy',
#        'red_training_accuracy', 'blue_training_accuracy',
#        'green_training_accuracy', 'yellow_training_accuracy',
# ...

# %%
datas = df_end[["shape_training_accuracy", "size_training_accuracy", "color_training_accuracy", "shape_test_accuracy", "size_test_accuracy","color_test_accuracy",
              "monomino_training_accuracy", "domino_training_accuracy", "tromino1_training_accuracy", "tromino2_training_accuracy",
              "tetromino1_training_accuracy", "tetromino2_training_accuracy", "tetromino3_training_accuracy", "tetromino4_training_accuracy",
              "tetromino5_training_accuracy", 'monomino_test_accuracy', 'domino_test_accuracy',
       'tromino1_test_accuracy', 'tromino2_test_accuracy',
       'tetromino1_test_accuracy', 'tetromino2_test_accuracy',
       'tetromino3_test_accuracy', 'tetromino4_test_accuracy',
       'tetromino5_test_accuracy']]

# %%
########### usual ###########

train_ = datas[["shape_training_accuracy", "size_training_accuracy", "color_training_accuracy", 
              "monomino_training_accuracy", "domino_training_accuracy", "tromino1_training_accuracy", "tromino2_training_accuracy",
              "tetromino1_training_accuracy", "tetromino2_training_accuracy", "tetromino3_training_accuracy", "tetromino4_training_accuracy",
              "tetromino5_training_accuracy"]]
test_ = datas[["shape_test_accuracy", "size_test_accuracy","color_test_accuracy", 'monomino_test_accuracy', 'domino_test_accuracy',
       'tromino1_test_accuracy', 'tromino2_test_accuracy',
       'tetromino1_test_accuracy', 'tetromino2_test_accuracy',
       'tetromino3_test_accuracy', 'tetromino4_test_accuracy',
       'tetromino5_test_accuracy']]
train = train_.values[0]
train_list = [train[0],train[1], train[2], train[3], train[4], (train[5]+train[6])/2, (train[7]+train[8]+train[9]+train[10]+train[11])/5]

test = test_.values[0]
test_list = [test[0],test[1], test[2], test[3], test[4], (test[5]+test[6])/2, (test[7]+test[8]+test[9]+test[10]+test[11])/5]

# train = train_.values  # for one row
# test = test_.values  # for one row

index = ['shape', 'size', 'color','monomino', 'domino', 'tromino1', 'tromino2',
         'tetromino1','tetromino2','tetromino3','tetromino4','tetromino5']
index_list = ['shape', 'size', 'color','monomino', 'domino', 'tromino','tetromino']

# %%
######## usual #######
# dff = pd.DataFrame({'train': train_list,'test': test_list}, index=index_list)
plotdata = pd.DataFrame({'train': train,'test': test}, index=index)
plotdata.plot(kind="bar")
plt.ylabel("Accuracy")
# plt.savefig('figures/1_complete_full_actions_train_6k_bar',bbox_inches='tight')
# plt.savefig('figures/1_complete_full_actions_train_1k_bar',bbox_inches='tight')
# plt.savefig('figures/2b_both_complete_omit_black_shape_bar',bbox_inches='tight')
# plt.savefig('figures/2c_top_bottom_train_top_test_bottom_check_first_stage_bar',bbox_inches='tight')
# plt.savefig('figures/2d_half_variant_train_first_test_omit_bar',bbox_inches='tight')

# plt.savefig('figures/3d_half_variant_complete_train_complete_test_second_stage_bar',bbox_inches='tight')
# plt.savefig('figures/2c_top_bottom_train_top_test_bottom_first_stage_bar',bbox_inches='tight')
# plt.savefig('figures/3c_top_bottom_train_top_test_bottom_first_train_bottom_test_bottom_second_stage_bar',bbox_inches='tight')

# %%
########### omit shape ###########
train_ = datas[["shape_training_accuracy", "size_training_accuracy", "color_training_accuracy", 
              "monomino_training_accuracy", "domino_training_accuracy", "tromino1_training_accuracy", "tromino2_training_accuracy",
              "tetromino1_training_accuracy", "tetromino2_training_accuracy", "tetromino3_training_accuracy", "tetromino4_training_accuracy",
              "tetromino5_training_accuracy"]]
test_ = datas[["shape_test_accuracy", "size_test_accuracy","color_test_accuracy", 'monomino_test_accuracy', 'domino_test_accuracy',
       'tromino1_test_accuracy', 'tromino2_test_accuracy',
       'tetromino1_test_accuracy', 'tetromino2_test_accuracy',
       'tetromino3_test_accuracy', 'tetromino4_test_accuracy',
       'tetromino5_test_accuracy']]

train = train_.values[0]
test = test_.values[0]

plotdata = pd.DataFrame({'train': train,'test': test}, 
    index=['shape', 'size', 'color','monomino', 'domino', 'tromino1', 'tromino2',
         'tetromino1','tetromino2','tetromino3','tetromino4','tetromino5'])

plotdata.plot(kind="bar")
plt.ylabel("Accuracy")
# plt.savefig('figures/2a_omit_tetro5_shape_first_train_both_complete_bar',bbox_inches='tight')
# plt.savefig('figures/3a_omit_tetro5_shape_second_stage_both_complete_bar',bbox_inches='tight')

# %%
######### omit color #########
train_ = df_end[["shape_training_accuracy", "size_training_accuracy", "color_training_accuracy", 
              'black_training_accuracy', 'white_training_accuracy',
       'red_training_accuracy', 'blue_training_accuracy',
       'green_training_accuracy', 'yellow_training_accuracy',
       'cyan_training_accuracy', 'magenta_training_accuracy']]
test_ = df_end[["shape_test_accuracy", "size_test_accuracy","color_test_accuracy", 'black_test_accuracy',
       'white_test_accuracy', 'red_test_accuracy', 'blue_test_accuracy',
       'green_test_accuracy', 'yellow_test_accuracy', 'cyan_test_accuracy',
       'magenta_test_accuracy']]

train = train_.values[0]
test = test_.values[0]

color_index = ['shape', 'size', 'color','black', 'white', 'red', 'blue', 'green', 'yellow', 'cyan', 'magenta']

plotdata = pd.DataFrame({'train': train,'test': test}, 
    index=color_index)

plotdata.plot(kind="bar")
plt.ylabel("Accuracy")
# plt.savefig("figures/3b_omit_magenta_color_both_complete_second_stage_bar.png",bbox_inches='tight')
# plt.savefig("figures/2b_omit_magenta_color_both_complete_first_stage_bar.png",bbox_inches='tight')
